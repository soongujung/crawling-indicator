# %%
from datetime import timedelta, date
import datetime
from calendar import monthrange

# %%
def daterange(start_date, end_date):
    for n in range(int ((end_date - start_date).days)):
        yield start_date + timedelta(n)

# %%
start_date = date(1970, 1, 1)
end_date = date(2040, 12, 31)
for single_date in daterange(start_date, end_date):
    print(single_date.strftime("%Y%m%d"))
# Out:
# 19700101
# 19700102
# 19700103
# 19700104
# 19700105
# 19700106
# 19700107
# 19700108
# 19700109
# 19700110
# 19700111
# 19700112
# 19700113
# 19700114
# 19700115
# 19700116
# 19700117
# 19700118
# 19700119
# 19700120
# 19700121
# 19700122
# 19700123
# 19700124
# 19700125
# 19700126
# 19700127
# 19700128
# 19700129
# 19700130
# 19700131
# 19700201
# 19700202
# 19700203
# 19700204
# 19700205
# 19700206
# 19700207
# 19700208
# 19700209
# 19700210
# 19700211
# 19700212
# 19700213
# 19700214
# 19700215
# 19700216
# 19700217
# 19700218
# 19700219
# 19700220
# 19700221
# 19700222
# 19700223
# 19700224
# 19700225
# 19700226
# 19700227
# 19700228
# 19700301
# 19700302
# 19700303
# 19700304
# 19700305
# 19700306
# 19700307
# 19700308
# 19700309
# 19700310
# 19700311
# 19700312
# 19700313
# 19700314
# 19700315
# 19700316
# 19700317
# 19700318
# 19700319
# 19700320
# 19700321
# 19700322
# 19700323
# 19700324
# 19700325
# 19700326
# 19700327
# 19700328
# 19700329
# 19700330
# 19700331
# ...

# %%
data = []

# %%
data.append(1)
data.append(2)

# %%
data
# Out:
# [1, 2]

# %%
str_start_time = "202001"
str_end_time = "202006"

# %%
date_start_time = datetime.datetime.strptime(str_start_time, '%Y%m')
date_end_time = datetime.datetime.strptime(str_end_time, '%Y%m')
# Out:
# datetime.datetime(2020, 1, 1, 0, 0)

# %%
# start_date = date(1970, 1, 1)
# end_date = date(2040, 12, 31)
# for single_date in daterange(start_date, end_date):
#     print(single_date.strftime("%Y%m%d"))

date_start = date_start_time.date()
date_start_len = monthrange(date_start_time.year,date_start_time.month)
date_start_len[1]
# date_end = date_start_time.date() + timedelta(date_start_time.)
# Out:
# 31

# %%
v = date_start + timedelta(date_start_len[1])

# %%
v
# Out:
# datetime.date(2020, 2, 1)

# %%
def daterange(start_date, end_date):
    for n in range(int((end_date - start_date).days)):
        yield start_date + timedelta(n)

# %%
for date_string in daterange(date_start, v):
    print(date_string.strftime("%Y%m%d"))
# Out:
# 20200101
# 20200102
# 20200103
# 20200104
# 20200105
# 20200106
# 20200107
# 20200108
# 20200109
# 20200110
# 20200111
# 20200112
# 20200113
# 20200114
# 20200115
# 20200116
# 20200117
# 20200118
# 20200119
# 20200120
# 20200121
# 20200122
# 20200123
# 20200124
# 20200125
# 20200126
# 20200127
# 20200128
# 20200129
# 20200130
# 20200131

# %%
datetime.datetime.min.time()
# Out:
# datetime.time(0, 0)
